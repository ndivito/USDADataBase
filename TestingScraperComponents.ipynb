# %%
import requests
import time
import os
import json
import string
import sqlite3

API_KEY = api_key = open("API_KEY.txt").read().strip()
  # Your USDA API key
BASE_URL = "https://api.nal.usda.gov/fdc/v1/foods/list"
FDC_DETAIL_PAGE_BASE = "https://fdc.nal.usda.gov/fdc-app.html#/food-details"
BASE_SEARCH_URL = "https://api.nal.usda.gov/fdc/v1/foods/search"
PAGE_SIZE = 200
MAX_PAGE_LIMIT = 250  # 50,000 results / 200 per page = 250 pages
SLEEP_DELAY = 0.5     # seconds between requests
RETRY_DELAY = 30      # seconds to wait on error retry
MAX_RETRIES = 3
MAX_DEPTH = 2         # Maximum additional characters to append for subdivision
CHECKPOINT_FILE = "checkpoint.json"
db_path = "branded_foods.db"

# %%
def create_tables(db_path: str):
    """
    Creates two tables:
      - food_items: stores abridged food item info including macros, derived metrics, 
        and additional fields (marketCountry, foodCategory, modifiedDate, dataSource, 
        servingSizeUnit, servingSize, householdServingFullText).
      - food_nutrients: stores all nutrient details for each food item.
    """
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()

    # Main table: store basic item info and key nutrient macros plus additional fields.
    cur.execute('''
        CREATE TABLE IF NOT EXISTS food_items (
            fdc_id INTEGER PRIMARY KEY,
            description TEXT,
            brand_owner TEXT,
            gtin_upc TEXT,
            published_date TEXT,
            market_country TEXT,
            food_category TEXT,
            modified_date TEXT,
            data_source TEXT,
            serving_size_unit TEXT,
            serving_size REAL,
            household_serving_full_text TEXT,
            protein_g REAL,
            fat_g REAL,
            carbs_g REAL,
            calories_kcal REAL,
            pct_protein_cal REAL
        )
    ''')

    # Secondary table: store all nutrient records.
    cur.execute('''
        CREATE TABLE IF NOT EXISTS food_nutrients (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            fdc_id INTEGER,
            nutrient_id INTEGER,
            nutrient_name TEXT,
            amount REAL,
            unit_name TEXT,
            derivation_code TEXT,
            derivation_description TEXT,
            FOREIGN KEY(fdc_id) REFERENCES food_items(fdc_id)
        )
    ''')

    conn.commit()
    conn.close()

# %%
def insert_branded_item(db_path: str, item: dict):
    """
    Inserts a single Branded food item into the database using the new food search schema.
    
    - Parses out nutrient 203 (Protein), 204 (Total lipid/fat), 205 (Carbohydrate, by difference),
      and 208 (Energy) using the new keys: 'nutrientNumber' and 'value'.
    - Uses 'publishedDate' for the item’s date.
    - Also extracts: marketCountry, foodCategory, modifiedDate, dataSource, servingSizeUnit,
      servingSize, and householdServingFullText.
    - Computes the derived field (pct_protein_cal) based on protein and energy.
    - Inserts all nutrient entries into the food_nutrients table.
    """
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()

    # Basic item fields.
    fdc_id = item.get("fdcId")
    description = item.get("description")
    brand_owner = item.get("brandOwner")
    gtin_upc = item.get("gtinUpc")
    published_date = item.get("publishedDate")
    market_country = item.get("marketCountry")
    food_category = item.get("foodCategory")
    modified_date = item.get("modifiedDate")
    data_source = item.get("dataSource")
    serving_size_unit = item.get("servingSizeUnit")
    serving_size = item.get("servingSize")
    household_serving_full_text = item.get("householdServingFullText")
    
    # Initialize macros with default 0 values.
    protein_g = 0
    fat_g = 0
    carbs_g = 0
    calories_kcal = 0

    # Process nutrient records.
    food_nutrients = item.get("foodNutrients", [])
    other_nutrients = []

    for nut in food_nutrients:
        try:
            num = nut.get("nutrientId")
        except (TypeError, ValueError):
            continue
        # In the new schema, the nutrient value is stored in "value"
        value = nut.get("value")
        
        if num == 1003:
            protein_g = value
        elif num == 1004:
            fat_g = value
        elif num == 1005:
            carbs_g = value
        elif num == 1008:
            calories_kcal = value
        
        other_nutrients.append(nut)

    # Compute derived percentage of protein calories.
    pct_protein_cal = 0
    if protein_g and calories_kcal and calories_kcal > 0:
        pct_protein_cal = (protein_g * 4 / calories_kcal) * 100

    # If calories are zero but macros are available, compute calories.
    if calories_kcal == 0 and protein_g and fat_g and carbs_g:
        calories_kcal = protein_g * 4 + fat_g * 9 + carbs_g * 4
        if calories_kcal > 0:
            pct_protein_cal = (protein_g * 4 / calories_kcal) * 100

    # Insert the main food item record into food_items.
    cur.execute('''
        INSERT OR REPLACE INTO food_items (
            fdc_id,
            description,
            brand_owner,
            gtin_upc,
            published_date,
            market_country,
            food_category,
            modified_date,
            data_source,
            serving_size_unit,
            serving_size,
            household_serving_full_text,
            protein_g,
            fat_g,
            carbs_g,
            calories_kcal,
            pct_protein_cal
        ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (
        fdc_id,
        description,
        brand_owner,
        gtin_upc,
        published_date,
        market_country,
        food_category,
        modified_date,
        data_source,
        serving_size_unit,
        serving_size,
        household_serving_full_text,
        protein_g,
        fat_g,
        carbs_g,
        calories_kcal,
        pct_protein_cal
    ))

    # Insert nutrient records into food_nutrients.
    for nut in other_nutrients:
        try:
            num = nut.get("nutrientId")
        except (TypeError, ValueError):
            num = None
        nutrient_name = nut.get("nutrientName")
        value = nut.get("value")
        unit_name = nut.get("unitName")
        deriv_code = nut.get("derivationCode")
        deriv_desc = nut.get("derivationDescription")
        
        cur.execute('''
            INSERT INTO food_nutrients (
                fdc_id,
                nutrient_id,
                nutrient_name,
                amount,
                unit_name,
                derivation_code,
                derivation_description
            ) VALUES (?, ?, ?, ?, ?, ?, ?)
        ''', (
            fdc_id,
            num,
            nutrient_name,
            value,
            unit_name,
            deriv_code,
            deriv_desc
        ))

    conn.commit()
    conn.close()

# %%
def load_checkpoint():
    """Load the task queue from the checkpoint file, if it exists."""
    if os.path.exists(CHECKPOINT_FILE):
        try:
            with open(CHECKPOINT_FILE, "r") as f:
                tasks = json.load(f)
                print("Checkpoint loaded with", len(tasks), "tasks.")
                return tasks
        except Exception as e:
            print("Error loading checkpoint:", e)
    return None

# %%
def save_checkpoint(tasks):
    """Save the current task queue to the checkpoint file."""
    with open(CHECKPOINT_FILE, "w") as f:
        json.dump(tasks, f)

# %%
def fetch_page(search_term, page_number):
    """Fetch a page of results for a given search term and page number."""
    body = {
        "generalSearchInput": search_term,
        "dataType": ["Branded"],
        "pageNumber": page_number,
        "pageSize": PAGE_SIZE,
        "sortBy": "fdcId",
        "sortOrder": "asc"
    }
    params = {"api_key": API_KEY}
    attempt = 0
    while attempt < MAX_RETRIES:
        try:
            response = requests.post(BASE_SEARCH_URL, json=body, params=params, timeout=30)
            response.raise_for_status()
            return response.json()
        except Exception as e:
            print(f"Error fetching page {page_number} for term '{search_term}': {e}")
            attempt += 1
            if attempt < MAX_RETRIES:
                print(f"Retrying in {RETRY_DELAY} seconds...")
                time.sleep(RETRY_DELAY)
    return None

# %%
def subdivide_task(task):
    """Subdivide a task into multiple sub-tasks by appending a character."""
    new_tasks = []
    for char in (string.ascii_lowercase + string.digits):
        new_tasks.append({
            "search_term": task["search_term"] + char,
            "depth": task["depth"] + 1,
            "current_page": 1,
            "total_pages": None,
            "completed": False
        })
    return new_tasks

# %%
def process_task(task):
    """
    Process a single task:
      - If total_pages is not set, fetch the first page to determine it.
      - If the total_pages exceed MAX_PAGE_LIMIT and depth is below MAX_DEPTH, subdivide.
      - Otherwise, paginate through all pages and insert items.
    Returns:
      - False if processing failed (so the task can be retried)
      - A list of new tasks if the task was subdivided
      - True if the task was processed successfully.
    """
    search_term = task["search_term"]
    current_page = task["current_page"]

    # Determine total_pages if not set.
    if task["total_pages"] is None:
        data = fetch_page(search_term, current_page)
        if data is None:
            return False  # Could not fetch; do not update task.
        total_pages = data.get("totalPages", 0)
        task["total_pages"] = total_pages
        print(f"Task '{search_term}' has {total_pages} pages at depth {task['depth']}")
    else:
        total_pages = task["total_pages"]

    # If too many pages, subdivide further (if depth allows).
    if total_pages > MAX_PAGE_LIMIT and task["depth"] < MAX_DEPTH:
        print(f"Task '{search_term}' at depth {task['depth']} too broad with {total_pages} pages; subdividing.")
        new_tasks = subdivide_task(task)
        task["completed"] = True  # Mark this task as subdivided.
        return new_tasks

    # Process pages.
    while current_page <= total_pages:
        data = fetch_page(search_term, current_page)
        if data is None:
            print(f"Skipping page {current_page} for term '{search_term}' after retries.")
            return False  # Let the task remain for retry.
        foods = data.get("foods", [])
        print(f"Processing term '{search_term}', page {current_page}/{total_pages} with {len(foods)} items.")
        for item in foods:
            insert_branded_item(db_path, item)
        current_page += 1
        task["current_page"] = current_page
        # Removed save_checkpoint call here.
        time.sleep(SLEEP_DELAY)
    task["completed"] = True
    return True

# %%
def ScrapeUSDA():
    create_tables(db_path)
    
    # Load checkpoint from file; if empty, initialize with seed tasks.
    task_queue = load_checkpoint()
    if not task_queue:
        task_queue = []
        for char in (list(string.ascii_lowercase) + list(string.digits)):
            task_queue.append({
                "search_term": char,
                "depth": 0,
                "current_page": 1,
                "total_pages": None,
                "completed": False
            })
        save_checkpoint(task_queue)
    
    # Process tasks until the queue is empty.
    while task_queue:
        task = task_queue.pop(0)
        if task.get("completed"):
            continue
        result = process_task(task)
        if result is False:
            # Processing failed; put task back for a later retry.
            task_queue.append(task)
        elif isinstance(result, list):
            # Task was subdivided; add new tasks.
            task_queue.extend(result)
        # Save checkpoint after processing each task.
        save_checkpoint(task_queue)
    
    print("Scraping complete.")

# %%
ScrapeUSDA()
# Out:
# Task 'a' has 1 pages at depth 0
# Processing term 'a', page 1/1 with 1 items.
# Task 'b' has 39 pages at depth 0
# Processing term 'b', page 1/39 with 200 items.
# Processing term 'b', page 2/39 with 200 items.
# Processing term 'b', page 3/39 with 200 items.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ScrapeUSDA()
#
# Cell In[16], line 23, in ScrapeUSDA()
#      21 if task.get("completed"):
#      22     continue
# ---> 23 result = process_task(task)
#      24 if result is False:
#      25     # Processing failed; put task back for a later retry.
#      26     task_queue.append(task)
#
# Cell In[15], line 42, in process_task(task)
#      40 print(f"Processing term '{search_term}', page {current_page}/{total_pages} with {len(foods)} items.")
#      41 for item in foods:
# ---> 42     insert_branded_item(db_path, item)
#      43 current_page += 1
#      44 task["current_page"] = current_page
#
# Cell In[3], line 143, in insert_branded_item(db_path, item)
#     121     deriv_desc = nut.get("derivationDescription")
#     123     cur.execute('''
#     124         INSERT INTO food_nutrients (
#     125             fdc_id,
#    (...)
#     140         deriv_desc
#     141     ))
# --> 143 conn.commit()
#     144 conn.close()
#
# KeyboardInterrupt:

# %% [markdown]
# # Quick Database top Check

# %%
conn = sqlite3.connect(db_path)
cur = conn.cursor()
cur.execute('''
    SELECT fdc_id, description, protein_g, calories_kcal, pct_protein_cal
    FROM food_items
    WHERE pct_protein_cal > 0
    ORDER BY pct_protein_cal DESC
''')
rows = cur.fetchall()
conn.close()

for row in rows:
    fdc_id, desc, prot, cals, pct = row
    print(f"FDC: {fdc_id}, Desc: {desc}, Protein_g: {prot}, Cals: {cals}, Pct_Protein_Cals: {pct:.2f}%")

# %% [markdown]
# # Query a single ID

# %%
import requests
import json

# Replace with your actual API key
API_KEY = "mpbbx23Q6NA8oDb52byDfdMYcukHRyaZED2eQ5VF"
BASE_URL = "https://api.nal.usda.gov/fdc/v1/food/{}"

def query_food_item(fdc_id):
    """
    Queries the USDA FoodData Central API for a single food item.
    
    Args:
        fdc_id (int): The FoodData Central ID.
    
    Returns:
        dict: The JSON response with the food item details.
    """
    url = BASE_URL.format(fdc_id)
    params = {"api_key": API_KEY, "format": ['abridged']}
    response = requests.get(url, params=params)
    response.raise_for_status()  # raise an exception for HTTP errors
    return response.json()

def main():
    try:
        fdc_id = int(input("Enter a USDA FDC ID: ").strip())
    except ValueError:
        print("Please enter a valid numeric FDC ID.")
        return

    try:
        data = query_food_item(fdc_id)
    except Exception as e:
        print(f"Error fetching data: {e}")
        return

    # Pretty-print the JSON details
    print("\n--- USDA Food Item Details ---\n")
    print(json.dumps(data, indent=2))

if __name__ == "__main__":
    main()
# Out:
# Enter a USDA FDC ID: 345355
#
# --- USDA Food Item Details ---
#
# {
#   "fdcId": 345355,
#   "description": "Honeysuckle White Boneless Turkey Roast with Gravy Packet",
#   "dataType": "Branded",
#   "publicationDate": "2019-04-01",
#   "brandOwner": "Cargill",
#   "gtinUpc": "00642205513826",
#   "foodNutrients": [
#     {
#       "number": "203",
#       "name": "Protein",
#       "amount": 23.0,
#       "unitName": "G",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "204",
#       "name": "Total lipid (fat)",
#       "amount": 2.5,
#       "unitName": "G",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "205",
#       "name": "Carbohydrate, by difference",
#       "amount": 1.0,
#       "unitName": "G",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "269",
#       "name": "Total Sugars",
#       "amount": 1.0,
#       "unitName": "G",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "291",
#       "name": "Fiber, total dietary",
#       "amount": 0.0,
#       "unitName": "G",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "307",
#       "name": "Sodium, Na",
#       "amount": 430,
#       "unitName": "MG",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "401",
#       "name": "Vitamin C, total ascorbic acid",
#       "amount": 0.0,
#       "unitName": "MG",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "601",
#       "name": "Cholesterol",
#       "amount": 60.0,
#       "unitName": "MG",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "605",
#       "name": "Fatty acids, total trans",
#       "amount": 0.0,
#       "unitName": "G",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     },
#     {
#       "number": "606",
#       "name": "Fatty acids, total saturated",
#       "amount": 0.5,
#       "unitName": "G",
#       "derivationCode": "LCGE",
#       "derivationDescription": "Given by information provider as an exact value per 100 unit measure"
#     }
#   ]
# }

# %% [markdown]
# # Query single page

# %%
def fetch_foods_list_get(page_number, page_size=200, max_retries=3, retry_delay=30):
    """
    Queries a single page of branded food items from USDA using a GET request.
    Implements retry logic to catch server errors.
    
    Args:
        page_number (int): The page number to fetch.
        page_size (int): Number of items per page (default is 200).
        max_retries (int): Number of retry attempts in case of error.
        retry_delay (int): Seconds to wait between retries.
    
    Returns:
        list: A list of food items (dictionaries) from the response, or an empty list if all attempts fail.
    """
    url = "https://api.nal.usda.gov/fdc/v1/foods/search"
    params = {
        "api_key": API_KEY,
        "dataType": "Branded",      # Restrict to Branded items
        "pageNumber": page_number,
        "pageSize": page_size,
        "sortBy": "fdcId",
        "sortOrder": "asc"
    }
    
    attempt = 0
    while attempt < max_retries:
        try:
            response = requests.get(url, params=params, timeout=30)
            response.raise_for_status()  # Will raise an HTTPError for 4xx/5xx responses
            data = response.json()
            if "foods" in data:
                return data["foods"]
            else:
                print(f"Unexpected response structure on page {page_number}: {data}")
                return []
        except requests.exceptions.HTTPError as http_err:
            print(f"HTTP error on page {page_number} (attempt {attempt+1}): {http_err}")
        except Exception as err:
            print(f"Error on page {page_number} (attempt {attempt+1}): {err}")
        attempt += 1
        if attempt < max_retries:
            print(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
    
    print(f"Failed to fetch page {page_number} after {max_retries} attempts.")
    return []

# Example usage:
if __name__ == "__main__":
    page = 251
    foods = fetch_foods_list_get(page)
    print(f"Fetched {len(foods)} items from page {page}")
# Out:
# HTTP error on page 251 (attempt 1): 500 Server Error: Internal Server Error for url: https://api.nal.usda.gov/fdc/v1/foods/search?api_key=mpbbx23Q6NA8oDb52byDfdMYcukHRyaZED2eQ5VF&dataType=Branded&pageNumber=251&pageSize=200&sortBy=fdcId&sortOrder=asc
# Retrying in 30 seconds...
# HTTP error on page 251 (attempt 2): 500 Server Error: Internal Server Error for url: https://api.nal.usda.gov/fdc/v1/foods/search?api_key=mpbbx23Q6NA8oDb52byDfdMYcukHRyaZED2eQ5VF&dataType=Branded&pageNumber=251&pageSize=200&sortBy=fdcId&sortOrder=asc
# Retrying in 30 seconds...
# HTTP error on page 251 (attempt 3): 500 Server Error: Internal Server Error for url: https://api.nal.usda.gov/fdc/v1/foods/search?api_key=mpbbx23Q6NA8oDb52byDfdMYcukHRyaZED2eQ5VF&dataType=Branded&pageNumber=251&pageSize=200&sortBy=fdcId&sortOrder=asc
# Failed to fetch page 251 after 3 attempts.
# Fetched 0 items from page 251

# %% [markdown]
# # Fetch Food list by page

# %%
def fetch_foods_list(page_number: int, page_size: int = 200) -> list:
    """
    Fetch a page of foods from USDA using the /foods/list endpoint.
    Returns a list of dicts (each representing a food item).
    An empty list means no more items.
    """
    # The USDA /foods/list endpoint requires a POST with JSON body specifying pageSize, pageNumber, etc.
    params = {
        "api_key": API_KEY
    }
    # Body for the POST request
    body = {
        "pageNumber": page_number,
        "pageSize": page_size,
        "sortBy": "fdcId",
        "sortOrder": "asc",
        "dataType": ["Branded"]
    }

    response = requests.post(BASE_URL, params=params, json=body)
    response.raise_for_status()
    return response.json()  # List of food items (or empty if no more pages)

# %%
json3 = fetch_foods_list(250,200)
json3[0]
# Out:
# {'fdcId': 1877488,
#  'description': 'THORNTONS, IRRESISTIBLES TRUFFLES, GINGERBREAD, GINGERBREAD',
#  'dataType': 'Branded',
#  'publicationDate': '2021-07-29',
#  'brandOwner': 'LBB Imports, LLC',
#  'gtinUpc': '813715013124',
#  'foodNutrients': [{'number': '203',
#    'name': 'Protein',
#    'amount': 4.76,
#    'unitName': 'G',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '204',
#    'name': 'Total lipid (fat)',
#    'amount': 31.0,
#    'unitName': 'G',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '205',
#    'name': 'Carbohydrate, by difference',
#    'amount': 54.8,
#    'unitName': 'G',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '208',
#    'name': 'Energy',
#    'amount': 500,
#    'unitName': 'KCAL',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '269',
#    'name': 'Total Sugars',
#    'amount': 42.9,
#    'unitName': 'G',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '291',
#    'name': 'Fiber, total dietary',
#    'amount': 4.8,
#    'unitName': 'G',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '301',
#    'name': 'Calcium, Ca',
#    'amount': 95.0,
#    'unitName': 'MG',
#    'derivationCode': 'LCCD',
#    'derivationDescription': 'Calculated from a daily value percentage per serving size measure'},
#   {'number': '303',
#    'name': 'Iron, Fe',
#    'amount': 1.71,
#    'unitName': 'MG',
#    'derivationCode': 'LCCD',
#    'derivationDescription': 'Calculated from a daily value percentage per serving size measure'},
#   {'number': '307',
#    'name': 'Sodium, Na',
#    'amount': 95.0,
#    'unitName': 'MG',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '318',
#    'name': 'Vitamin A, IU',
#    'amount': 0.0,
#    'unitName': 'IU',
#    'derivationCode': 'LCCD',
#    'derivationDescription': 'Calculated from a daily value percentage per serving size measure'},
#   {'number': '401',
#    'name': 'Vitamin C, total ascorbic acid',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'LCCD',
#    'derivationDescription': 'Calculated from a daily value percentage per serving size measure'},
#   {'number': '601',
#    'name': 'Cholesterol',
#    'amount': 24.0,
#    'unitName': 'MG',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '605',
#    'name': 'Fatty acids, total trans',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'},
#   {'number': '606',
#    'name': 'Fatty acids, total saturated',
#    'amount': 19.0,
#    'unitName': 'G',
#    'derivationCode': 'LCCS',
#    'derivationDescription': 'Calculated from value per serving size measure'}]}

# %% [markdown]
# # Fetch Results By Search GET

# %%
def fetch_page_get(search_term, page_number):
    """
    Fetch a page of results for a given search term and page number using a GET request.
    
    Args:
        search_term (str): The search query.
        page_number (int): The page number to fetch.
    
    Returns:
        dict: The JSON response from the API, or None on failure.
    """
    import requests
    import time
    
    url = "https://api.nal.usda.gov/fdc/v1/foods/search"
    params = {
        "api_key": API_KEY,
        "generalSearchInput": search_term,
        "dataType": "Branded",  # using only Branded items
        "pageNumber": page_number,
        "pageSize": PAGE_SIZE,
        "sortBy": "fdcId",
        "sortOrder": "asc"
    }
    
    attempt = 0
    while attempt < MAX_RETRIES:
        try:
            response = requests.get(url, params=params, timeout=30)
            response.raise_for_status()
            return response.json()
        except Exception as e:
            print(f"Error fetching page {page_number} for term '{search_term}' using GET (attempt {attempt+1}): {e}")
            attempt += 1
            if attempt < MAX_RETRIES:
                print(f"Retrying in {RETRY_DELAY} seconds...")
                time.sleep(RETRY_DELAY)
    return None

# %%
json2 = fetch_page_get('ab', 1)
json2
# Out:
# {'totalHits': 155,
#  'currentPage': 1,
#  'totalPages': 1,
#  'pageList': [1],
#  'foodSearchCriteria': {'dataType': ['Branded'],
#   'generalSearchInput': 'ab',
#   'pageNumber': 1,
#   'sortBy': 'fdcId',
#   'sortOrder': 'asc',
#   'numberOfResultsPerPage': 50,
#   'pageSize': 200,
#   'requireAllWords': False,
#   'foodTypes': ['Branded']},
#  'foods': [{'fdcId': 1031871,
#    'description': 'SOUR RASPBERRY CANDY FISH, SOUR RASPBERRY',
#    'dataType': 'Branded',
#    'gtinUpc': '7350010277767',
#    'publishedDate': '2020-06-26',
#    'brandOwner': 'KOLSVART AB',
#    'ingredients': 'SUGAR, INVERT SUGAR SYRUP, WATER,CORN STARCH, GLUCOSE SYRUP, CITRIC ACID, TARTARIC ACID, CARROT CONCENTRATE, NATURAL RASPBERRY AROMA, COCONUT OIL, CARNAUBA WAX',
#    'marketCountry': 'United States',
#    'foodCategory': 'Candy',
#    'modifiedDate': '2020-04-08',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'g',
#    'servingSize': 30.0,
#    'householdServingFullText': '6 PCS',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: KOLSVART <em>AB</em>',
#    'score': -407.46796,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 600,
#      'indentLevel': 1,
#      'foodNutrientId': 12035735,
#      'percentDailyValue': 0},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 12035737,
#      'percentDailyValue': 0},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 86.7,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 12035739,
#      'percentDailyValue': 9},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 367,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 12035741,
#      'percentDailyValue': 0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 73.3,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 12035743,
#      'percentDailyValue': 0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 12035745,
#      'percentDailyValue': 0},
#     {'nutrientId': 1235,
#      'nutrientName': 'Sugars, added',
#      'nutrientNumber': '539',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 73.3,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1540,
#      'indentLevel': 0,
#      'foodNutrientId': 12035747,
#      'percentDailyValue': 44}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '4', 'name': 'Nutrient Updated', 'id': 873191},
#     {'value': '5', 'name': 'Nutrient Added', 'id': 873189}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '4',
#        'name': 'Nutrient Updated',
#        'id': 873191},
#       {'value': '5', 'name': 'Nutrient Added', 'id': 873189}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1092261,
#    'description': 'MALTED MILK DRINK MIX, MALTED MILK',
#    'dataType': 'Branded',
#    'gtinUpc': '7612100054314',
#    'publishedDate': '2020-09-29',
#    'brandOwner': 'AB FOOD & BEVERAGES (THAILAND) LTD',
#    'ingredients': 'INGREDIENTS: BARLEY AND MALT EXTRACT, WHOLE MILK POWDER, WHEY POWDER, SUGAR, PALM OIL, BUTTER OIL, OLIGOFRUCTOSE, SODIUM BICARBONATE, SALT.',
#    'marketCountry': 'United States',
#    'foodCategory': 'Powdered Drinks',
#    'modifiedDate': '2020-07-31',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'g',
#    'servingSize': 35.0,
#    'householdServingFullText': '4 tablespoons',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: <em>AB</em> FOOD & BEVERAGES (THAILAND) LTD',
#    'score': -410.54117,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 8.57,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 600,
#      'indentLevel': 1,
#      'foodNutrientId': 12804453,
#      'percentDailyValue': 0},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 11.4,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 12804455,
#      'percentDailyValue': 6},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 74.3,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 12804457,
#      'percentDailyValue': 9},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 429,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 12804459,
#      'percentDailyValue': 0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 48.6,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 12804461,
#      'percentDailyValue': 0},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1200,
#      'indentLevel': 3,
#      'foodNutrientId': 12804463,
#      'percentDailyValue': 0},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 286,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5300,
#      'indentLevel': 1,
#      'foodNutrientId': 12804465,
#      'percentDailyValue': 10},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5400,
#      'indentLevel': 1,
#      'foodNutrientId': 12804467,
#      'percentDailyValue': 0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 400,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 12804469,
#      'percentDailyValue': 6},
#     {'nutrientId': 1104,
#      'nutrientName': 'Vitamin A, IU',
#      'nutrientNumber': '318',
#      'unitName': 'IU',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 1140.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 7500,
#      'indentLevel': 1,
#      'foodNutrientId': 12804471,
#      'percentDailyValue': 8},
#     {'nutrientId': 1162,
#      'nutrientName': 'Vitamin C, total ascorbic acid',
#      'nutrientNumber': '401',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 6300,
#      'indentLevel': 1,
#      'foodNutrientId': 12804473,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 29.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 12804475,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 7.14,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 12804477,
#      'percentDailyValue': 13}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '2', 'name': 'Description', 'id': 956441}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '2', 'name': 'Description', 'id': 956441}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1126267,
#    'description': 'GINGER, APPLE, LEMON, CHILI PEPPER 100% JUICE, GINGER',
#    'dataType': 'Branded',
#    'gtinUpc': '7350088710333',
#    'publishedDate': '2020-11-13',
#    'brandOwner': 'WELLNOX AB',
#    'ingredients': 'ORGANIC APPLE JUICE FROM CONCENTRATE, ORGANIC GINGER, ORGANIC LEMON JUICE, ORGANIC CHILI PEPPER. PASTEURIZED.',
#    'marketCountry': 'United States',
#    'foodCategory': 'Fruit & Vegetable Juice, Nectars & Fruit Drinks',
#    'modifiedDate': '2020-04-08',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'ml',
#    'servingSize': 240.0,
#    'householdServingFullText': '8 OZA',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: WELLNOX <em>AB</em>',
#    'score': -407.46796,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 0.62,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 600,
#      'indentLevel': 1,
#      'foodNutrientId': 13666711},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666712,
#      'percentDailyValue': 0},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 7.29,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 13666713,
#      'percentDailyValue': 6.199999809265137},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 40.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 13666714},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 6.25,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 13666715},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666716,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666717,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666718,
#      'percentDailyValue': 0}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '5', 'name': 'Nutrient Added', 'id': 1042014},
#     {'value': '4', 'name': 'Nutrient Updated', 'id': 1042015}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '5',
#        'name': 'Nutrient Added',
#        'id': 1042014},
#       {'value': '4', 'name': 'Nutrient Updated', 'id': 1042015}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1126373,
#    'description': 'TURMERIC, SEA BUCKTHORN, GINGER, CARROT, APPLE, PEAR DRINK, TURMERIC, SEA BUCKTHORN, GINGER, CARROT, APPLE, PEAR',
#    'dataType': 'Branded',
#    'gtinUpc': '7350088710326',
#    'publishedDate': '2020-11-13',
#    'brandOwner': 'WELLNOX AB',
#    'ingredients': 'ORGANIC PEAR JUICE FROM CONCENTRATE, ORGANIC JUICES FROM APPLE, GINGER, TURMERIC, SEA BUCKTHORN AND ORGANIC CARROT FROM CONCENTRATE. PASTEURIZED.',
#    'marketCountry': 'United States',
#    'foodCategory': 'Fruit & Vegetable Juice, Nectars & Fruit Drinks',
#    'modifiedDate': '2020-04-08',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'ml',
#    'servingSize': 240.0,
#    'householdServingFullText': '8 OZA',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: WELLNOX <em>AB</em>',
#    'score': -407.46796,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 0.62,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 600,
#      'indentLevel': 1,
#      'foodNutrientId': 13666719},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666720,
#      'percentDailyValue': 0},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 11.5,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 13666721,
#      'percentDailyValue': 9.5},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 48.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 13666722},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 8.21,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 13666723},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666724,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666725,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666726,
#      'percentDailyValue': 0}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '5', 'name': 'Nutrient Added', 'id': 1042221},
#     {'value': '4', 'name': 'Nutrient Updated', 'id': 1042220}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '5',
#        'name': 'Nutrient Added',
#        'id': 1042221},
#       {'value': '4', 'name': 'Nutrient Updated', 'id': 1042220}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1126411,
#    'description': 'BALANCE, ORGANIC BEET JUICE, LINGONBERRY JUICE, BEET, LINGONBERRY',
#    'dataType': 'Branded',
#    'gtinUpc': '7350088710227',
#    'publishedDate': '2020-11-13',
#    'brandOwner': 'WELLNOX AB',
#    'ingredients': 'ORGANIC BEET JUICE FROM CONCENTRATE, LINGONBERRY JUICE FROM CONCENTRATE.',
#    'marketCountry': 'United States',
#    'foodCategory': 'Fruit & Vegetable Juice, Nectars & Fruit Drinks',
#    'modifiedDate': '2020-04-08',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'ml',
#    'servingSize': 240.0,
#    'householdServingFullText': '8 OZA',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: WELLNOX <em>AB</em>',
#    'score': -407.46796,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 0.9,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 600,
#      'indentLevel': 1,
#      'foodNutrientId': 13666702,
#      'percentDailyValue': 0},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666703,
#      'percentDailyValue': 0},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 8.21,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 13666704,
#      'percentDailyValue': 6.5},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 38.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 13666705},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 7.71,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 13666706},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCSL',
#      'derivationDescription': 'Calculated from a less than value per serving size measure',
#      'derivationId': 73,
#      'value': 0.4,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1200,
#      'indentLevel': 3,
#      'foodNutrientId': 13666707,
#      'percentDailyValue': 1},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666708,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666709,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666710,
#      'percentDailyValue': 0}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '4',
#      'name': 'Nutrient Updated',
#      'id': 1042294},
#     {'value': '5', 'name': 'Nutrient Added', 'id': 1042293}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '4',
#        'name': 'Nutrient Updated',
#        'id': 1042294},
#       {'value': '5', 'name': 'Nutrient Added', 'id': 1042293}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1126457,
#    'description': 'LEMON, GINGER DRINK, LEMON, GINGER',
#    'dataType': 'Branded',
#    'gtinUpc': '7350088710340',
#    'publishedDate': '2020-11-13',
#    'brandOwner': 'WELLNOX AB',
#    'ingredients': 'WATER, ORGANIC LEMON JUICE, ORGANIC GINGER.',
#    'marketCountry': 'United States',
#    'foodCategory': 'Other Drinks',
#    'modifiedDate': '2020-04-08',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'ml',
#    'servingSize': 240.0,
#    'householdServingFullText': '8 OZA',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: WELLNOX <em>AB</em>',
#    'score': -407.46796,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 0.12,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 600,
#      'indentLevel': 1,
#      'foodNutrientId': 13666694},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666695,
#      'percentDailyValue': 0},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 1.67,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 13666696,
#      'percentDailyValue': 1},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 8.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 13666697},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 0.54,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 13666698},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666699,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666700,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666701,
#      'percentDailyValue': 0}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '4',
#      'name': 'Nutrient Updated',
#      'id': 1042386},
#     {'value': '5', 'name': 'Nutrient Added', 'id': 1042387}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '4',
#        'name': 'Nutrient Updated',
#        'id': 1042386},
#       {'value': '5', 'name': 'Nutrient Added', 'id': 1042387}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1126521,
#    'description': 'ARONIA, BERRY JUICE, ARONIA',
#    'dataType': 'Branded',
#    'gtinUpc': '7350088710357',
#    'publishedDate': '2020-11-13',
#    'brandOwner': 'WELLNOX AB',
#    'ingredients': 'ORGANIC ARONIA BERRY JUICE, WATER.',
#    'marketCountry': 'United States',
#    'foodCategory': 'Fruit & Vegetable Juice, Nectars & Fruit Drinks',
#    'modifiedDate': '2020-04-08',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'ml',
#    'servingSize': 240.0,
#    'householdServingFullText': '8 OZA',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: WELLNOX <em>AB</em>',
#    'score': -407.46796,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666736,
#      'percentDailyValue': 0},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 11.5,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 13666737,
#      'percentDailyValue': 9.5},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 47.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 13666738},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 11.5,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 13666739},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666740,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666741,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666742,
#      'percentDailyValue': 0}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '4',
#      'name': 'Nutrient Updated',
#      'id': 1042511},
#     {'value': '5', 'name': 'Nutrient Added', 'id': 1042510}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '4',
#        'name': 'Nutrient Updated',
#        'id': 1042511},
#       {'value': '5', 'name': 'Nutrient Added', 'id': 1042510}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1136539,
#    'description': 'XTRA BEET SUPERCHARGED 4X BEET JUICE, LINGONBERRY JUICE, XTRA BEET',
#    'dataType': 'Branded',
#    'gtinUpc': '7350088710142',
#    'publishedDate': '2020-11-13',
#    'brandOwner': 'WELLNOX AB',
#    'ingredients': 'BEET JUICE FROM CONCENTRATE, LINGONBERRY JUICE FROM CONCENTRATE. PASTEURIZED.',
#    'marketCountry': 'United States',
#    'foodCategory': 'Fruit & Vegetable Juice, Nectars & Fruit Drinks',
#    'modifiedDate': '2020-04-08',
#    'dataSource': 'LI',
#    'servingSizeUnit': 'ml',
#    'servingSize': 125.0,
#    'householdServingFullText': '4 OZA',
#    'tradeChannels': ['NO_TRADE_CHANNEL'],
#    'allHighlightFields': '<b>Brand Owner</b>: WELLNOX <em>AB</em>',
#    'score': -407.46796,
#    'microbes': [],
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 1.76,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 600,
#      'indentLevel': 1,
#      'foodNutrientId': 13666727},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666728,
#      'percentDailyValue': 0},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 13.6,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1110,
#      'indentLevel': 2,
#      'foodNutrientId': 13666729,
#      'percentDailyValue': 5.900000095367432},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 63.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 13666730},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'derivationId': 70,
#      'value': 12.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 13666731},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCSL',
#      'derivationDescription': 'Calculated from a less than value per serving size measure',
#      'derivationId': 73,
#      'value': 0.8,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1200,
#      'indentLevel': 3,
#      'foodNutrientId': 13666732,
#      'percentDailyValue': 1},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 13666733,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666734,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'derivationId': 75,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 13666735,
#      'percentDailyValue': 0}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [{'value': '4',
#      'name': 'Nutrient Updated',
#      'id': 1062564},
#     {'value': '5', 'name': 'Nutrient Added', 'id': 1062565}],
#    'foodAttributeTypes': [{'name': 'Update Log',
#      'description': 'Changes that were made to this food',
#      'id': 998,
#      'foodAttributes': [{'value': '4',
#        'name': 'Nutrient Updated',
#        'id': 1062564},
#       {'value': '5', 'name': 'Nutrient Added', 'id': 1062565}]}],
#    'foodVersionIds': []},
#   {'fdcId': 1159387,
#    'description': 'CLASSIC MALT DRINK MIX, CLASSIC MALT',
#    'dataType': 'Branded',
#    'gtinUpc': '7612100054321',
#    'publishedDate': '2021-01-28',
#    'brandOwner': 'AB FOOD & BEVERAGES (THAILAND) LTD.',
# ...
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 362,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 300,
#      'indentLevel': 1,
#      'foodNutrientId': 34595609,
#      'percentDailyValue': 0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Total Sugars',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 1.02,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1510,
#      'indentLevel': 3,
#      'foodNutrientId': 34595610,
#      'percentDailyValue': 0},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 2.4,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1200,
#      'indentLevel': 3,
#      'foodNutrientId': 34595611,
#      'percentDailyValue': 8.560714721679688},
#     {'nutrientId': 1082,
#      'nutrientName': 'Fiber, soluble',
#      'nutrientNumber': '295',
#      'unitName': 'G',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1240,
#      'indentLevel': 4,
#      'foodNutrientId': 34595612,
#      'percentDailyValue': 0},
#     {'nutrientId': 1084,
#      'nutrientName': 'Fiber, insoluble',
#      'nutrientNumber': '297',
#      'unitName': 'G',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1260,
#      'indentLevel': 4,
#      'foodNutrientId': 34595613,
#      'percentDailyValue': 0},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 21.1,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5300,
#      'indentLevel': 1,
#      'foodNutrientId': 34595614,
#      'percentDailyValue': 1.6233845949172974},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 1.26,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5400,
#      'indentLevel': 1,
#      'foodNutrientId': 34595615,
#      'percentDailyValue': 6.988888740539551},
#     {'nutrientId': 1090,
#      'nutrientName': 'Magnesium, Mg',
#      'nutrientNumber': '304',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 36200.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5500,
#      'indentLevel': 1,
#      'foodNutrientId': 34595616,
#      'percentDailyValue': 8.615714073181152},
#     {'nutrientId': 1091,
#      'nutrientName': 'Phosphorus, P',
#      'nutrientNumber': '305',
#      'unitName': 'MG',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5600,
#      'indentLevel': 1,
#      'foodNutrientId': 34595617,
#      'percentDailyValue': 0},
#     {'nutrientId': 1092,
#      'nutrientName': 'Potassium, K',
#      'nutrientNumber': '306',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 125,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5700,
#      'indentLevel': 1,
#      'foodNutrientId': 34595618,
#      'percentDailyValue': 2.650404214859009},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 2.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5800,
#      'indentLevel': 1,
#      'foodNutrientId': 34595619,
#      'percentDailyValue': 0.08686956763267517},
#     {'nutrientId': 1095,
#      'nutrientName': 'Zinc, Zn',
#      'nutrientNumber': '309',
#      'unitName': 'MG',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 5900,
#      'indentLevel': 1,
#      'foodNutrientId': 34595620,
#      'percentDailyValue': 0},
#     {'nutrientId': 1106,
#      'nutrientName': 'Vitamin A, RAE',
#      'nutrientNumber': '320',
#      'unitName': 'UG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 7420,
#      'indentLevel': 1,
#      'foodNutrientId': 34595621,
#      'percentDailyValue': 0},
#     {'nutrientId': 1114,
#      'nutrientName': 'Vitamin D (D2 + D3)',
#      'nutrientNumber': '328',
#      'unitName': 'UG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 8700,
#      'indentLevel': 1,
#      'foodNutrientId': 34595622,
#      'percentDailyValue': 0},
#     {'nutrientId': 1162,
#      'nutrientName': 'Vitamin C, total ascorbic acid',
#      'nutrientNumber': '401',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 6300,
#      'indentLevel': 1,
#      'foodNutrientId': 34595623,
#      'percentDailyValue': 0},
#     {'nutrientId': 1165,
#      'nutrientName': 'Thiamin',
#      'nutrientNumber': '404',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.194,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 6400,
#      'indentLevel': 1,
#      'foodNutrientId': 34595624,
#      'percentDailyValue': 16.14708709716797},
#     {'nutrientId': 1166,
#      'nutrientName': 'Riboflavin',
#      'nutrientNumber': '405',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.0719,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 6500,
#      'indentLevel': 1,
#      'foodNutrientId': 34595625,
#      'percentDailyValue': 5.531754016876221},
#     {'nutrientId': 1167,
#      'nutrientName': 'Niacin',
#      'nutrientNumber': '406',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 1.2,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 6600,
#      'indentLevel': 1,
#      'foodNutrientId': 34595626,
#      'percentDailyValue': 7.4784321784973145},
#     {'nutrientId': 1175,
#      'nutrientName': 'Vitamin B-6',
#      'nutrientNumber': '415',
#      'unitName': 'MG',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 6800,
#      'indentLevel': 1,
#      'foodNutrientId': 34595627,
#      'percentDailyValue': 0},
#     {'nutrientId': 1177,
#      'nutrientName': 'Folate, total',
#      'nutrientNumber': '417',
#      'unitName': 'UG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 31.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 6900,
#      'indentLevel': 1,
#      'foodNutrientId': 34595628,
#      'percentDailyValue': 7.740614414215088},
#     {'nutrientId': 1178,
#      'nutrientName': 'Vitamin B-12',
#      'nutrientNumber': '418',
#      'unitName': 'UG',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 7300,
#      'indentLevel': 1,
#      'foodNutrientId': 34595629,
#      'percentDailyValue': 0},
#     {'nutrientId': 1186,
#      'nutrientName': 'Folic acid',
#      'nutrientNumber': '431',
#      'unitName': 'UG',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 7000,
#      'indentLevel': 0,
#      'foodNutrientId': 34595630,
#      'percentDailyValue': 0},
#     {'nutrientId': 1235,
#      'nutrientName': 'Sugars, added',
#      'nutrientNumber': '539',
#      'unitName': 'G',
#      'derivationCode': 'LCGP',
#      'derivationDescription': 'Given by information provider as a value per 100 unit measure',
#      'derivationId': 76,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 1540,
#      'indentLevel': 0,
#      'foodNutrientId': 34595631,
#      'percentDailyValue': 0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15700,
#      'indentLevel': 1,
#      'foodNutrientId': 34595632,
#      'percentDailyValue': 0},
#     {'nutrientId': 1257,
#      'nutrientName': 'Fatty acids, total trans',
#      'nutrientNumber': '605',
#      'unitName': 'G',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.0,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 15400,
#      'indentLevel': 1,
#      'foodNutrientId': 34595633,
#      'percentDailyValue': 0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.223,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 9700,
#      'indentLevel': 1,
#      'foodNutrientId': 34595634,
#      'percentDailyValue': 1.1150000095367432},
#     {'nutrientId': 1292,
#      'nutrientName': 'Fatty acids, total monounsaturated',
#      'nutrientNumber': '645',
#      'unitName': 'G',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.152,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 11400,
#      'indentLevel': 1,
#      'foodNutrientId': 34595635,
#      'percentDailyValue': 0},
#     {'nutrientId': 1293,
#      'nutrientName': 'Fatty acids, total polyunsaturated',
#      'nutrientNumber': '646',
#      'unitName': 'G',
#      'derivationCode': 'LCGA',
#      'derivationDescription': 'Given by information provider as an approximate value per 100 unit measure',
#      'derivationId': 78,
#      'value': 0.694,
#      'foodNutrientSourceId': 9,
#      'foodNutrientSourceCode': '12',
#      'foodNutrientSourceDescription': "Manufacturer's analytical; partial documentation",
#      'rank': 12900,
#      'indentLevel': 1,
#      'foodNutrientId': 34595636,
#      'percentDailyValue': 0}],
#    'finalFoodInputFoods': [],
#    'foodMeasures': [],
#    'foodAttributes': [],
#    'foodAttributeTypes': [],
#    'foodVersionIds': []}],
#  'aggregations': {'dataType': {'Branded': 155}, 'nutrients': {}}}
